# %% [markdown]
# 1. Load and preprocess dataset

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# Load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# One-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Normalize before data augmentation
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
)

# Fit the data augmentation on training data
datagen.fit(X_train)

def generator_with_flatten(datagen, X, y, batch_size):
    gen = datagen.flow(X, y, batch_size=batch_size)
    while True:
        X_batch, y_batch = next(gen)
        yield X_batch, y_batch

# Configure the generator
batch_size = 128
train_generator = generator_with_flatten(datagen, X_train, y_train, batch_size)

# Reshape test data only (no augmentation needed for test)
#X_test = X_test.reshape(-1, 32*32*3)
# Out:
# 2025-07-19 22:56:22.866611: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-19 22:56:22.869017: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-19 22:56:22.875798: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752958582.887676   18439 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752958582.891177   18439 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752958582.900076   18439 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752958582.900089   18439 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752958582.900090   18439 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752958582.900091   18439 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-19 22:56:22.903459: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import matplotlib.pyplot as plt

# Display 16 images in a 4x4 grid
fig, axes = plt.subplots(4, 4, figsize=(8, 8))
fig.suptitle('Sample Images from CIFAR-10 Dataset', fontsize=16)

for i, ax in enumerate(axes.flat):
    ax.imshow(X_train[i].reshape(32, 32, 3))
    ax.axis('off')

plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()

# %%
# Display the same 16 images from the original dataset but augmented
indices = list(range(16))
original_images = X_train[indices]
augmented_images, _ = next(datagen.flow(original_images, y_train[indices], batch_size=16))

fig, axes = plt.subplots(4, 4, figsize=(8, 8))
fig.suptitle('Augmented Versions of the Same 16 Images', fontsize=16)

for i, ax in enumerate(axes.flat):
    ax.imshow(augmented_images[i].reshape(32, 32, 3))
    ax.axis('off')

plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# 2. Define the Dense model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential([
    Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)),
    BatchNormalization(),
    Conv2D(32, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
# Out:
# /home/albert/Documents/projects/Cifar-10-image-classifier/venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1752953332.955109    7072 cuda_executor.cc:1228] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1752953332.955451    7072 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# 3. Compile model

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# 4. Training

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
history = model.fit(datagen.flow(X_train, y_train, batch_size=64),
                    validation_data=(X_test, y_test),
                    epochs=50, 
                    callbacks=[lr_schedule])
# Out:
# Epoch 1/50
# /home/albert/Documents/projects/Cifar-10-image-classifier/venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 114ms/step - accuracy: 0.3766 - loss: 1.9957 - val_accuracy: 0.5910 - val_loss: 1.1418 - learning_rate: 0.0010
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.5677 - loss: 1.2144 - val_accuracy: 0.5559 - val_loss: 1.4542 - learning_rate: 0.0010
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.6241 - loss: 1.0631 - val_accuracy: 0.5901 - val_loss: 1.3055 - learning_rate: 0.0010
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.6577 - loss: 0.9709 - val_accuracy: 0.6422 - val_loss: 1.1049 - learning_rate: 0.0010
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 108ms/step - accuracy: 0.6764 - loss: 0.9209 - val_accuracy: 0.6950 - val_loss: 0.9266 - learning_rate: 0.0010
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 103ms/step - accuracy: 0.7037 - loss: 0.8425 - val_accuracy: 0.6965 - val_loss: 0.8851 - learning_rate: 0.0010
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.7109 - loss: 0.8228 - val_accuracy: 0.7509 - val_loss: 0.7712 - learning_rate: 0.0010
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 104ms/step - accuracy: 0.7259 - loss: 0.7858 - val_accuracy: 0.7367 - val_loss: 0.8192 - learning_rate: 0.0010
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 105ms/step - accuracy: 0.7319 - loss: 0.7728 - val_accuracy: 0.7385 - val_loss: 0.7900 - learning_rate: 0.0010
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.7466 - loss: 0.7341 - val_accuracy: 0.7686 - val_loss: 0.7061 - learning_rate: 0.0010
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.7547 - loss: 0.7111 - val_accuracy: 0.6970 - val_loss: 0.9558 - learning_rate: 0.0010
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.7589 - loss: 0.7015 - val_accuracy: 0.7497 - val_loss: 0.7693 - learning_rate: 0.0010
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.7624 - loss: 0.6827 - val_accuracy: 0.7797 - val_loss: 0.6602 - learning_rate: 0.0010
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.7693 - loss: 0.6683 - val_accuracy: 0.7630 - val_loss: 0.7293 - learning_rate: 0.0010
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.7794 - loss: 0.6457 - val_accuracy: 0.7663 - val_loss: 0.6950 - learning_rate: 0.0010
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 109ms/step - accuracy: 0.7768 - loss: 0.6420 - val_accuracy: 0.7557 - val_loss: 0.7624 - learning_rate: 0.0010
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.7842 - loss: 0.6229 - val_accuracy: 0.7995 - val_loss: 0.5961 - learning_rate: 0.0010
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.7847 - loss: 0.6136 - val_accuracy: 0.7789 - val_loss: 0.6713 - learning_rate: 0.0010
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.7848 - loss: 0.6137 - val_accuracy: 0.7650 - val_loss: 0.7333 - learning_rate: 0.0010
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.7912 - loss: 0.5961 - val_accuracy: 0.7848 - val_loss: 0.6484 - learning_rate: 0.0010
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 108ms/step - accuracy: 0.7964 - loss: 0.5822 - val_accuracy: 0.7779 - val_loss: 0.6879 - learning_rate: 0.0010
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7995 - loss: 0.5691
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 107ms/step - accuracy: 0.7995 - loss: 0.5691 - val_accuracy: 0.7801 - val_loss: 0.6751 - learning_rate: 0.0010
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.8059 - loss: 0.5615 - val_accuracy: 0.8211 - val_loss: 0.5378 - learning_rate: 5.0000e-04
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.8136 - loss: 0.5391 - val_accuracy: 0.8116 - val_loss: 0.5594 - learning_rate: 5.0000e-04
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.8203 - loss: 0.5203 - val_accuracy: 0.8239 - val_loss: 0.5316 - learning_rate: 5.0000e-04
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.8151 - loss: 0.5301 - val_accuracy: 0.8031 - val_loss: 0.6211 - learning_rate: 5.0000e-04
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.8204 - loss: 0.5115 - val_accuracy: 0.7999 - val_loss: 0.6188 - learning_rate: 5.0000e-04
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.8198 - loss: 0.5129 - val_accuracy: 0.8183 - val_loss: 0.5587 - learning_rate: 5.0000e-04
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.8278 - loss: 0.4972 - val_accuracy: 0.8342 - val_loss: 0.4996 - learning_rate: 5.0000e-04
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.8246 - loss: 0.5019 - val_accuracy: 0.8287 - val_loss: 0.5254 - learning_rate: 5.0000e-04
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.8281 - loss: 0.5000 - val_accuracy: 0.8300 - val_loss: 0.5079 - learning_rate: 5.0000e-04
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.8270 - loss: 0.4915 - val_accuracy: 0.8204 - val_loss: 0.5493 - learning_rate: 5.0000e-04
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.8334 - loss: 0.4828 - val_accuracy: 0.8414 - val_loss: 0.4691 - learning_rate: 5.0000e-04
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.8311 - loss: 0.4837 - val_accuracy: 0.8135 - val_loss: 0.5808 - learning_rate: 5.0000e-04
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.8295 - loss: 0.4823 - val_accuracy: 0.8289 - val_loss: 0.5268 - learning_rate: 5.0000e-04
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.8357 - loss: 0.4733 - val_accuracy: 0.8210 - val_loss: 0.5531 - learning_rate: 5.0000e-04
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.8338 - loss: 0.4722 - val_accuracy: 0.8383 - val_loss: 0.4837 - learning_rate: 5.0000e-04
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8354 - loss: 0.4783
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.8354 - loss: 0.4783 - val_accuracy: 0.8375 - val_loss: 0.4928 - learning_rate: 5.0000e-04
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.8371 - loss: 0.4654 - val_accuracy: 0.8387 - val_loss: 0.4872 - learning_rate: 2.5000e-04
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.8409 - loss: 0.4567 - val_accuracy: 0.8458 - val_loss: 0.4676 - learning_rate: 2.5000e-04
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 109ms/step - accuracy: 0.8419 - loss: 0.4570 - val_accuracy: 0.8463 - val_loss: 0.4697 - learning_rate: 2.5000e-04
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.8438 - loss: 0.4495 - val_accuracy: 0.8399 - val_loss: 0.4858 - learning_rate: 2.5000e-04
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.8419 - loss: 0.4447 - val_accuracy: 0.8458 - val_loss: 0.4671 - learning_rate: 2.5000e-04
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.8397 - loss: 0.4604 - val_accuracy: 0.8353 - val_loss: 0.5082 - learning_rate: 2.5000e-04
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.8480 - loss: 0.4441 - val_accuracy: 0.8465 - val_loss: 0.4636 - learning_rate: 2.5000e-04
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 100s 128ms/step - accuracy: 0.8465 - loss: 0.4373 - val_accuracy: 0.8447 - val_loss: 0.4721 - learning_rate: 2.5000e-04
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 100s 127ms/step - accuracy: 0.8479 - loss: 0.4384 - val_accuracy: 0.8331 - val_loss: 0.5229 - learning_rate: 2.5000e-04
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.8469 - loss: 0.4310 - val_accuracy: 0.8338 - val_loss: 0.5133 - learning_rate: 2.5000e-04
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.8459 - loss: 0.4391 - val_accuracy: 0.8470 - val_loss: 0.4747 - learning_rate: 2.5000e-04
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8532 - loss: 0.4242
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 112ms/step - accuracy: 0.8532 - loss: 0.4242 - val_accuracy: 0.8466 - val_loss: 0.4671 - learning_rate: 2.5000e-04

# %% [markdown]
# 5. Evaluation and visualization

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train acc')
plt.plot(history.history['val_accuracy'], label='Val acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Dense-only CIFAR-10 Classifier Accuracy')
plt.grid(True)
plt.show()

# Evaluación final
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {test_acc*100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8464 - loss: 0.4764
#
# Test Accuracy: 84.66%
